# %% [markdown]
# # [Flight API](https://www.flightapi.io/docs/) Data Pipeline
# The purpose of this notebook is show my steps and thought process of building a pipeline from an inital REST API Call.

# %% [markdown]
# ## Purpose and Goals of Project
# Overall, flight information across various sources is constantly scattered from a range of different airports, airlines, and locations. The goal and value of this project is to pull data from different sources and organize such data sources that can then be viewed directly or later used as source of visualization. With this, a user can clearly see insightful flight information across differing sources in an organized fashion.

# %% [markdown]
# ### Notes and Possible Areas of Improvement :
# After completing this project, there are a couple things that can be improved upon to increase efficiency and further promote better standards which I will technically address in the future. First, since this notebook does not contain any form of orchestration I am actively learning and improving my skills in Databricks to implement orchestration tools and other languages that could be of use like Pyspark, Scala or SQL. Additionally, while starting this project I was quite unfamilarly with working with json files of such a complex form (as shown in the variable dict1). Because of this, I decided to work with the key of most significance, define a function which flattens data and then create a pandas dataframe from such data. Although this method works well in this case, in the future I plan on instead working directly with the json file, ridding unneccessary information from there and then creating the dataframe in order to follow best practice standards, promoting efficiency.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/marcmedina/opt/anaconda3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/marcmedina/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/marcmedina/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marcmedina/opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marcmedina/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import
import requests
import pandas as pd
import json
import datetime
import pytz

# %% [markdown]
# ## API Call and Initial Exploration

# %%
# Perform API call and output response code, '200' meaning a success
url = "https://api.flightapi.io/schedule/63e3f3ebc750d7e9767923c2?mode=departures&day=1&iata=DOH"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
# Assign to dictionary and reduce documentation
dict1=response.json()
dict1=dict1['airport']['pluginData']
dict1
# Out:
# {'details': {'name': 'Doha Hamad International Airport',
#   'code': {'iata': 'DOH', 'icao': 'OTHH'},
#   'delayIndex': {'arrivals': 0.42, 'departures': 1.73},
#   'stats': {'arrivals': {'delayIndex': 0.42,
#     'delayAvg': 5,
#     'percentage': {'delayed': 0, 'canceled': 0, 'trend': 'down'},
#     'recent': {'delayIndex': 0.42,
#      'delayAvg': 5,
#      'percentage': {'delayed': 0, 'canceled': 0, 'trend': 'down'},
#      'quantity': {'onTime': 9, 'delayed': 0, 'canceled': 0}},
#     'today': {'percentage': {'delayed': 0.01, 'canceled': 0.01},
#      'quantity': {'onTime': 26, 'delayed': 3, 'canceled': 2}},
#     'yesterday': {'percentage': {'delayed': 0.16, 'canceled': 0.01},
#      'quantity': {'onTime': 248, 'delayed': 47, 'canceled': 2}},
#     'tomorrow': {'percentage': {'canceled': 0.01},
#      'quantity': {'canceled': 4}}},
#    'departures': {'delayIndex': 1.73,
#     'delayAvg': 20,
#     'percentage': {'delayed': 0.75, 'canceled': 0.01, 'trend': 'down'},
#     'recent': {'delayIndex': 1.73,
#      'delayAvg': 20,
#      'percentage': {'delayed': 0.75, 'canceled': 0.01, 'trend': 'down'},
#      'quantity': {'onTime': 18, 'delayed': 57, 'canceled': 1}},
#     'today': {'percentage': {'delayed': 0.19, 'canceled': 0.02},
#      'quantity': {'onTime': 22, 'delayed': 62, 'canceled': 6}},
#     'yesterday': {'percentage': {'delayed': 0.63, 'canceled': 0.01},
#      'quantity': {'onTime': 109, 'delayed': 193, 'canceled': 2}},
#     'tomorrow': {'percentage': {'canceled': 0.01},
#      'quantity': {'canceled': 4}}}},
#   'position': {'latitude': 25.272524,
#    'longitude': 51.608604,
#    'elevation': 13,
#    'country': {'name': 'Qatar', 'code': 'QA', 'id': 179},
#    'region': {'city': 'Doha'}},
#   'timezone': {'name': 'Asia/Qatar',
#    'offset': 10800,
#    'abbr': '+03',
#    'abbrName': None,
#    'isDst': False},
#   'url': {'homepage': 'http://www.dohaairport.com/',
#    'webcam': None,
#    'wikipedia': 'https://en.wikipedia.org/wiki/Hamad_International_Airport'},
#   'airportImages': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/12432_1668021850_tb.jpg',
#      'link': 'https://www.jetphotos.com/photo/10775378',
#      'copyright': 'Emmanuel NARGIL',
#      'source': 'Jetphotos.com'},
#     {'src': 'https://cdn.jetphotos.com/200/6/90049_1422800586_tb.jpg',
#      'link': 'https://www.jetphotos.com/photo/7976131',
#      'copyright': 'Sebastian Thiel',
#      'source': 'Jetphotos.com'}],
#    'medium': [{'src': 'https://cdn.jetphotos.com/400/6/12432_1668021850.jpg',
#      'link': 'https://www.jetphotos.com/photo/10775378',
#      'copyright': 'Emmanuel NARGIL',
#      'source': 'Jetphotos.com'},
#     {'src': 'https://cdn.jetphotos.com/400/6/90049_1422800586.jpg',
#      'link': 'https://www.jetphotos.com/photo/7976131',
#      'copyright': 'Sebastian Thiel',
#      'source': 'Jetphotos.com'}],
#    'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/12432_1668021850.jpg',
#      'link': 'https://www.jetphotos.com/photo/10775378',
#      'copyright': 'Emmanuel NARGIL',
#      'source': 'Jetphotos.com'},
#     {'src': 'https://cdn.jetphotos.com/640cb/6/90049_1422800586.jpg',
#      'link': 'https://www.jetphotos.com/photo/7976131',
#      'copyright': 'Sebastian Thiel',
#      'source': 'Jetphotos.com'}]},
#   'visible': True},
#  'flightdiary': {'url': '/data/airports/doh/reviews',
#   'ratings': {'avg': 4.63, 'total': 835},
#   'comment': [{'content': 'Very large spacious airport but had to be bussed to remote stand and waited for some time before boarding',
#     'author': {'facebookId': None, 'name': 'FAB4'},
#     'timestamp': 1678959362}],
#   'reviews': 15,
#   'evaluation': 93},
#  'schedule': {'departures': {'item': {'current': 100,
#     'total': 473,
#     'limit': 100},
#    'page': {'current': 1, 'total': 5},
#    'timestamp': 1680138120,
#    'data': [{'flight': {'identification': {'id': None,
#        'row': 5341427706,
#        'number': {'default': 'QR8434', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '77X', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#         'timezone': {'name': 'Asia/Bangkok',
#          'offset': 25200,
#          'abbr': '+07',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Bangkok Suvarnabhumi Airport',
#         'position': {'latitude': 13.6811,
#          'longitude': 100.7472,
#          'country': {'name': 'Thailand', 'code': 'TH', 'id': 221},
#          'region': {'city': 'Bangkok'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680138300, 'arrival': 1680161100},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5343637775,
#        'number': {'default': 'QR8360', 'alternative': '9T8360'},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '74Y', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'HKG', 'icao': 'VHHH'},
#         'timezone': {'name': 'Asia/Hong_Kong',
#          'offset': 28800,
#          'abbr': 'HKT',
#          'abbrName': 'Hong Kong Time',
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Hong Kong International Airport',
#         'position': {'latitude': 22.309616,
#          'longitude': 113.916237,
#          'country': {'name': 'Hong Kong', 'code': 'HK', 'id': 99},
#          'region': {'city': 'Hong Kong'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680138600, 'arrival': 1680168600},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5344268274,
#        'number': {'default': 'QR1166', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['VA6208',
#         'WB1178',
#         'WY6470',
#         'AA8204',
#         'BA2327',
#         'CX9215',
#         'IB870',
#         'LA5624',
#         'MH4138']},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '320', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C81'}},
#        'destination': {'code': {'iata': 'RUH', 'icao': 'OERK'},
#         'timezone': {'name': 'Asia/Riyadh',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': 'T3', 'baggage': None, 'gate': None},
#         'name': 'Riyadh King Khalid International Airport',
#         'position': {'latitude': 24.95764,
#          'longitude': 46.698769,
#          'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#          'region': {'city': 'Riyadh'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680139800, 'arrival': 1680145200},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427024,
#        'number': {'default': 'QR1190', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['WY6482',
#         'MH4148',
#         'CX9308',
#         'IB902',
#         'BA2360',
#         'AA8263',
#         'VA6071']},
#       'status': {'live': False,
#        'text': 'Estimated dep 04:40',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680140400, 'local': 1680151200}}},
#       'aircraft': {'model': {'code': '320', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'A11'}},
#        'destination': {'code': {'iata': 'JED', 'icao': 'OEJN'},
#         'timezone': {'name': 'Asia/Riyadh',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': '1', 'baggage': None, 'gate': None},
#         'name': 'Jeddah King Abdulaziz International Airport',
#         'position': {'latitude': 21.67956,
#          'longitude': 39.156528,
#          'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#          'region': {'city': 'Jeddah'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680140400, 'arrival': 1680149700},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680140400, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5343637776,
#        'number': {'default': 'QR8111', 'alternative': None},
#        'callsign': 'QTR8111',
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 04:55',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680141300, 'local': 1680152100}}},
#       'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-F'},
#        'registration': 'A7-BFT',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A2E1',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Cargo',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'MXP', 'icao': 'LIMC'},
#         'timezone': {'name': 'Europe/Rome',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Milan Malpensa Airport',
#         'position': {'latitude': 45.6306,
#          'longitude': 8.728111,
#          'country': {'name': 'Italy', 'code': 'IT', 'id': 109},
#          'region': {'city': 'Milan'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680140700, 'arrival': 1680163200},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680141300, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427729,
#        'number': {'default': 'QR8696', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '77X', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'BLR', 'icao': 'VOBL'},
#         'timezone': {'name': 'Asia/Kolkata',
#          'offset': 19800,
#          'abbr': 'IST',
#          'abbrName': 'India Standard Time',
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Bengaluru Kempegowda International Airport',
#         'position': {'latitude': 13.198889,
#          'longitude': 77.705559,
#          'country': {'name': 'India', 'code': 'IN', 'id': 102},
#          'region': {'city': 'Bengaluru'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680143700, 'arrival': 1680158100},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5344453849,
#        'number': {'default': 'MH6124', 'alternative': None},
#        'callsign': 'MAS6124',
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 05:55',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680144900, 'local': 1680155700}}},
#       'aircraft': {'model': {'code': 'A332', 'text': 'Airbus A330-223F'},
#        'registration': '9M-MUA',
#        'country': {'id': 133,
#         'name': 'Malaysia',
#         'alpha2': 'MY',
#         'alpha3': 'MYS'},
#        'hex': '750263',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Malaysia Airlines',
#        'code': {'iata': 'MH', 'icao': 'MAS'},
#        'logo': 's3:MH_MAS.png'},
#       'airline': {'name': 'MASkargo',
#        'code': {'iata': 'MH', 'icao': 'MAS'},
#        'short': 'Malaysia Airlines'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'AMS', 'icao': 'EHAM'},
#         'timezone': {'name': 'Europe/Amsterdam',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Amsterdam Schiphol Airport',
#         'position': {'latitude': 52.308609,
#          'longitude': 4.763889,
#          'country': {'name': 'Netherlands', 'code': 'NL', 'id': 155},
#          'region': {'city': 'Amsterdam'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680144300, 'arrival': 1680169020},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680144900, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341438568,
#        'number': {'default': 'TK783', 'alternative': None},
#        'callsign': 'THY5TA',
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 06:05',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680145500, 'local': 1680156300}}},
#       'aircraft': {'model': {'code': 'A21N', 'text': 'Airbus A321-271NX'},
#        'registration': 'TC-LSU',
#        'country': {'id': 228,
#         'name': 'Turkey',
#         'alpha2': 'TR',
#         'alpha3': 'TUR'},
#        'hex': '4BB275',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Turkish Airlines',
#        'code': {'iata': 'TK', 'icao': 'THY'},
#        'logo': 's3:TK_THY.png'},
#       'airline': {'name': 'Turkish Airlines',
#        'code': {'iata': 'TK', 'icao': 'THY'},
#        'short': 'Turkish Airlines'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': '1', 'baggage': None, 'gate': 'B7'}},
#        'destination': {'code': {'iata': 'IST', 'icao': 'LTFM'},
#         'timezone': {'name': 'Europe/Istanbul',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Istanbul Airport',
#         'position': {'latitude': 41.267052,
#          'longitude': 28.729757,
#          'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#          'region': {'city': 'Istanbul'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680144900, 'arrival': 1680161100},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680145500, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427712,
#        'number': {'default': 'QR8511', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '77X', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'KWI', 'icao': 'OKKK'},
#         'timezone': {'name': 'Asia/Kuwait',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Kuwait International Airport',
#         'position': {'latitude': 29.226561,
#          'longitude': 47.968922,
#          'country': {'name': 'Kuwait', 'code': 'KW', 'id': 118},
#          'region': {'city': 'Kuwait City'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680145800, 'arrival': 1680151500},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5343637777,
#        'number': {'default': 'QR8482', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '77X', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'KWI', 'icao': 'OKKK'},
#         'timezone': {'name': 'Asia/Kuwait',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Kuwait International Airport',
#         'position': {'latitude': 29.226561,
#          'longitude': 47.968922,
#          'country': {'name': 'Kuwait', 'code': 'KW', 'id': 118},
#          'region': {'city': 'Kuwait City'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680146100, 'arrival': 1680151500},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341428431,
#        'number': {'default': 'RJ651', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['QR6100']},
#       'status': {'live': False,
#        'text': 'Estimated dep 06:35',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680147300, 'local': 1680158100}}},
#       'aircraft': {'model': {'code': '319', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Royal Jordanian',
#        'code': {'iata': 'RJ', 'icao': 'RJA'},
#        'short': 'Royal Jordanian'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'A1'}},
#        'destination': {'code': {'iata': 'AMM', 'icao': 'OJAI'},
#         'timezone': {'name': 'Asia/Amman',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': '120'},
#         'name': 'Amman Queen Alia International Airport',
#         'position': {'latitude': 31.722549,
#          'longitude': 35.99321,
#          'country': {'name': 'Jordan', 'code': 'JO', 'id': 113},
#          'region': {'city': 'Amman'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680147300, 'arrival': 1680157800},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680147300, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341425852,
#        'number': {'default': 'QR239', 'alternative': None},
#        'callsign': 'QTR4C',
#        'codeshare': ['CX9239',
#         'VA6093',
#         'UL3120',
#         'WY6319',
#         'MH9319',
#         'WB1037']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:15',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680149700, 'local': 1680160500}}},
#       'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-367(ER)'},
#        'registration': 'A7-BOB',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A373',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C82'}},
#        'destination': {'code': {'iata': 'IST', 'icao': 'LTFM'},
#         'timezone': {'name': 'Europe/Istanbul',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': 'I', 'baggage': '16', 'gate': None},
#         'name': 'Istanbul Airport',
#         'position': {'latitude': 41.267052,
#          'longitude': 28.729757,
#          'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#          'region': {'city': 'Istanbul'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680149700, 'arrival': 1680165900},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680149700, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341426990,
#        'number': {'default': 'QR1178', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['IB868',
#         'VA6142',
#         'WY6476',
#         'BA2366',
#         'MH4142',
#         'CX9236']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:15',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680149700, 'local': 1680160500}}},
#       'aircraft': {'model': {'code': '320', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'A4'}},
#        'destination': {'code': {'iata': 'MED', 'icao': 'OEMA'},
#         'timezone': {'name': 'Asia/Riyadh',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Medina Prince Mohammad bin Abdulaziz Airport',
#         'position': {'latitude': 24.553419,
#          'longitude': 39.705059,
#          'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#          'region': {'city': 'Medina'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680149700, 'arrival': 1680158400},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680149700, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341426536,
#        'number': {'default': 'QR773', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['CX9373', 'LA5261']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:30',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680150600, 'local': 1680161400}}},
#       'aircraft': {'model': {'code': '77W', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C23'}},
#        'destination': {'code': {'iata': 'GRU', 'icao': 'SBGR'},
#         'timezone': {'name': 'America/Sao_Paulo',
#          'offset': -10800,
#          'abbr': '-03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': '3', 'baggage': None, 'gate': None},
#         'name': 'Sao Paulo Guarulhos International Airport',
#         'position': {'latitude': -23.431999,
#          'longitude': -46.469501,
#          'country': {'name': 'Brazil', 'code': 'BR', 'id': 32},
#          'region': {'city': 'Sao Paulo'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680150600, 'arrival': 1680202500},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680150600, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427698,
#        'number': {'default': 'QR8253', 'alternative': '9T8253'},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Canceled',
#        'icon': 'red',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'canceled',
#          'type': 'departure',
#          'color': 'red',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '74Y', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'CDG', 'icao': 'LFPG'},
#         'timezone': {'name': 'Europe/Paris',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Paris Charles de Gaulle Airport',
#         'position': {'latitude': 49.012516,
#          'longitude': 2.555752,
#          'country': {'name': 'France', 'code': 'FR', 'id': 76},
#          'region': {'city': 'Paris'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680150600, 'arrival': 1680172200},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341425771,
#        'number': {'default': 'QR175', 'alternative': None},
#        'callsign': 'QTR61W',
#        'codeshare': ['MH9265',
#         'AY6665',
#         'WB1029',
#         'VA6062',
#         'UL3485',
#         'WY6309']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:35',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680150900, 'local': 1680161700}}},
#       'aircraft': {'model': {'code': 'B789',
#         'text': 'Boeing 787-9 Dreamliner'},
#        'registration': 'A7-BHO',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A2F2',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'A11'}},
#        'destination': {'code': {'iata': 'OSL', 'icao': 'ENGM'},
#         'timezone': {'name': 'Europe/Oslo',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Oslo Gardermoen Airport',
#         'position': {'latitude': 60.193909,
#          'longitude': 11.10036,
#          'country': {'name': 'Norway', 'code': 'NO', 'id': 165},
#          'region': {'city': 'Oslo'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680150900, 'arrival': 1680176400},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680150900, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427041,
#        'number': {'default': 'QR1206', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['CX9218', 'AA8296', 'VA6204', 'IB2415']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:35',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680150900, 'local': 1680161700}}},
#       'aircraft': {'model': {'code': '320', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C83'}},
#        'destination': {'code': {'iata': 'TIF', 'icao': 'OETF'},
#         'timezone': {'name': 'Asia/Riyadh',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Taif Airport',
#         'position': {'latitude': 21.48341,
#          'longitude': 40.544331,
#          'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#          'region': {'city': 'Taif'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680150900, 'arrival': 1680159600},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680150900, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341425817,
#        'number': {'default': 'QR203', 'alternative': None},
#        'callsign': 'QTR45B',
#        'codeshare': ['MH9279', 'CX9231', 'WY6124', 'VA6036']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:40',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680151200, 'local': 1680162000}}},
#       'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-2DZ(LR)'},
#        'registration': 'A7-BBE',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A075',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C36'}},
#        'destination': {'code': {'iata': 'ATH', 'icao': 'LGAV'},
#         'timezone': {'name': 'Europe/Athens',
#          'offset': 10800,
#          'abbr': 'EEST',
#          'abbrName': 'Eastern European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Athens Eleftherios Venizelos',
#         'position': {'latitude': 37.936352,
#          'longitude': 23.94446,
#          'country': {'name': 'Greece', 'code': 'GR', 'id': 86},
#          'region': {'city': 'Athens'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680151200, 'arrival': 1680168600},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680151200, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341426053,
#        'number': {'default': 'QR482', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['WY6185']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:40',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680151200, 'local': 1680162000}}},
#       'aircraft': {'model': {'code': '332', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C43'}},
#        'destination': {'code': {'iata': 'IKA', 'icao': 'OIIE'},
#         'timezone': {'name': 'Asia/Tehran',
#          'offset': 12600,
#          'abbr': '+0330',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Tehran Imam Khomeini International Airport',
#         'position': {'latitude': 35.416111,
#          'longitude': 51.152222,
#          'country': {'name': 'Iran', 'code': 'IR', 'id': 104},
#          'region': {'city': 'Tehran'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680151200, 'arrival': 1680159000},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680151200, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341426872,
#        'number': {'default': 'QR1038', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:40',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680151200, 'local': 1680162000}}},
#       'aircraft': {'model': {'code': '320', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C81'}},
#        'destination': {'code': {'iata': 'SHJ', 'icao': 'OMSJ'},
#         'timezone': {'name': 'Asia/Dubai',
#          'offset': 14400,
#          'abbr': '+04',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': '1', 'gate': None},
#         'name': 'Sharjah International Airport',
#         'position': {'latitude': 25.328569,
#          'longitude': 55.517151,
#          'country': {'name': 'United Arab Emirates', 'code': 'AE', 'id': 234},
#          'region': {'city': 'Sharjah'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680151200, 'arrival': 1680155400},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680151200, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341425558,
#        'number': {'default': 'QR39', 'alternative': None},
#        'callsign': None,
#        'codeshare': ['UL3539', 'MH9215', 'WY6289', 'VA6024']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:45',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680151500, 'local': 1680162300}}},
#       'aircraft': {'model': {'code': '77W', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'A10'}},
#        'destination': {'code': {'iata': 'CDG', 'icao': 'LFPG'},
#         'timezone': {'name': 'Europe/Paris',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': '1', 'baggage': None, 'gate': None},
#         'name': 'Paris Charles de Gaulle Airport',
#         'position': {'latitude': 49.012516,
#          'longitude': 2.555752,
#          'country': {'name': 'France', 'code': 'FR', 'id': 76},
#          'region': {'city': 'Paris'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680177300},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680151500, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341426005,
#        'number': {'default': 'QR416', 'alternative': None},
#        'callsign': 'QTR62R',
#        'codeshare': ['ME4435', 'AT5804', 'WY6138', 'VA6055', 'LA7410']},
#       'status': {'live': False,
#        'text': 'Estimated dep 07:45',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680151500, 'local': 1680162300}}},
#       'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#        'registration': 'A7-AHE',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A08E',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C80'}},
#        'destination': {'code': {'iata': 'BEY', 'icao': 'OLBA'},
#         'timezone': {'name': 'Asia/Beirut',
#          'offset': 10800,
#          'abbr': 'EEST',
#          'abbrName': 'Eastern European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Beirut Rafic Hariri International Airport',
#         'position': {'latitude': 33.82093,
#          'longitude': 35.48838,
#          'country': {'name': 'Lebanon', 'code': 'LB', 'id': 122},
#          'region': {'city': 'Beirut'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680161700},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680151500, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
# ...
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'B7'}},
#        'destination': {'code': {'iata': 'KTM', 'icao': 'VNKT'},
#         'timezone': {'name': 'Asia/Kathmandu',
#          'offset': 20700,
#          'abbr': '+0545',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': 'I', 'baggage': None, 'gate': None},
#         'name': 'Kathmandu Tribhuvan International Airport',
#         'position': {'latitude': 27.696581,
#          'longitude': 85.3591,
#          'country': {'name': 'Nepal', 'code': 'NP', 'id': 154},
#          'region': {'city': 'Kathmandu'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680156900, 'arrival': 1680174000},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5343637808,
#        'number': {'default': 'QR8062', 'alternative': None},
#        'callsign': 'QTR8062',
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 09:25',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680157500, 'local': 1680168300}}},
#       'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-FDZ'},
#        'registration': 'A7-BFO',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A1EC',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Cargo',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'MAD', 'icao': 'LEMD'},
#         'timezone': {'name': 'Europe/Madrid',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Madrid Barajas Airport',
#         'position': {'latitude': 40.488701,
#          'longitude': -3.57,
#          'country': {'name': 'Spain', 'code': 'ES', 'id': 209},
#          'region': {'city': 'Madrid'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680156900, 'arrival': 1680184500},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680157500, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427721,
#        'number': {'default': 'QR8572', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Canceled',
#        'icon': 'red',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'canceled',
#          'type': 'departure',
#          'color': 'red',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '74N', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'JED', 'icao': 'OEJN'},
#         'timezone': {'name': 'Asia/Riyadh',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Jeddah King Abdulaziz International Airport',
#         'position': {'latitude': 21.67956,
#          'longitude': 39.156528,
#          'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#          'region': {'city': 'Jeddah'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680157200, 'arrival': 1680166800},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5344274334,
#        'number': {'default': 'QR634', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '333', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C84'}},
#        'destination': {'code': {'iata': 'DAC', 'icao': 'VGHS'},
#         'timezone': {'name': 'Asia/Dhaka',
#          'offset': 21600,
#          'abbr': '+06',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Dhaka Shahjalal International Airport',
#         'position': {'latitude': 23.84333,
#          'longitude': 90.397781,
#          'country': {'name': 'Bangladesh', 'code': 'BD', 'id': 19},
#          'region': {'city': 'Dhaka'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680158100, 'arrival': 1680178500},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341425787,
#        'number': {'default': 'QR183', 'alternative': None},
#        'callsign': 'QTR53L',
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 09:45',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680158700, 'local': 1680169500}}},
#       'aircraft': {'model': {'code': 'B788',
#         'text': 'Boeing 787-8 Dreamliner'},
#        'registration': 'A7-BCX',
#        'country': {'id': 179,
#         'name': 'Qatar',
#         'alpha2': 'QA',
#         'alpha3': 'QAT'},
#        'hex': '06A0BC',
#        'restricted': False,
#        'serialNo': None,
#        'age': {'availability': True},
#        'availability': {'serialNo': True, 'age': True}},
#       'owner': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'logo': 's3:QR_QTR.png'},
#       'airline': {'name': 'Qatar Airways (25 Years of Excellence Sticker)',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'C86'}},
#        'destination': {'code': {'iata': 'VIE', 'icao': 'LOWW'},
#         'timezone': {'name': 'Europe/Vienna',
#          'offset': 7200,
#          'abbr': 'CEST',
#          'abbrName': 'Central European Summer Time',
#          'isDst': True},
#         'info': {'terminal': '3', 'baggage': None, 'gate': None},
#         'name': 'Vienna International Airport',
#         'position': {'latitude': 48.110271,
#          'longitude': 16.569719,
#          'country': {'name': 'Austria', 'code': 'AT', 'id': 15},
#          'region': {'city': 'Vienna'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680158700, 'arrival': 1680179700},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680158700, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341376983,
#        'number': {'default': 'G9136', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 09:55',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680159300, 'local': 1680170100}}},
#       'aircraft': {'model': {'code': '320', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Air Arabia',
#        'code': {'iata': 'G9', 'icao': 'ABY'},
#        'short': 'Air Arabia'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'B10'}},
#        'destination': {'code': {'iata': 'SHJ', 'icao': 'OMSJ'},
#         'timezone': {'name': 'Asia/Dubai',
#          'offset': 14400,
#          'abbr': '+04',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': '2', 'gate': None},
#         'name': 'Sharjah International Airport',
#         'position': {'latitude': 25.328569,
#          'longitude': 55.517151,
#          'country': {'name': 'United Arab Emirates', 'code': 'AE', 'id': 234},
#          'region': {'city': 'Sharjah'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680159300, 'arrival': 1680162900},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680159300, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341366446,
#        'number': {'default': 'FZ2', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Estimated dep 10:00',
#        'icon': 'green',
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'estimated',
#          'type': 'departure',
#          'color': 'green',
#          'diverted': None},
#         'eventTime': {'utc': 1680159600, 'local': 1680170400}}},
#       'aircraft': {'model': {'code': '7M8', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'FlyDubai',
#        'code': {'iata': 'FZ', 'icao': 'FDB'},
#        'short': 'FlyDubai'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': 'B5'}},
#        'destination': {'code': {'iata': 'DXB', 'icao': 'OMDB'},
#         'timezone': {'name': 'Asia/Dubai',
#          'offset': 14400,
#          'abbr': '+04',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': '2', 'baggage': '1', 'gate': None},
#         'name': 'Dubai International Airport',
#         'position': {'latitude': 25.252769,
#          'longitude': 55.364441,
#          'country': {'name': 'United Arab Emirates', 'code': 'AE', 'id': 234},
#          'region': {'city': 'Dubai'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680159600, 'arrival': 1680164100},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': 1680159600, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}},
#     {'flight': {'identification': {'id': None,
#        'row': 5341427671,
#        'number': {'default': 'QR8094', 'alternative': None},
#        'callsign': None,
#        'codeshare': None},
#       'status': {'live': False,
#        'text': 'Scheduled',
#        'icon': None,
#        'estimated': None,
#        'ambiguous': False,
#        'generic': {'status': {'text': 'scheduled',
#          'type': 'departure',
#          'color': 'gray',
#          'diverted': None},
#         'eventTime': {'utc': None, 'local': None}}},
#       'aircraft': {'model': {'code': '77X', 'text': ''},
#        'hex': '',
#        'registration': '',
#        'serialNo': '',
#        'images': None},
#       'owner': None,
#       'airline': {'name': 'Qatar Airways',
#        'code': {'iata': 'QR', 'icao': 'QTR'},
#        'short': 'Qatar Airways'},
#       'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#          'offset': 10800,
#          'abbr': '+03',
#          'abbrName': None,
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None}},
#        'destination': {'code': {'iata': 'CCU', 'icao': 'VECC'},
#         'timezone': {'name': 'Asia/Kolkata',
#          'offset': 19800,
#          'abbr': 'IST',
#          'abbrName': 'India Standard Time',
#          'isDst': False},
#         'info': {'terminal': None, 'baggage': None, 'gate': None},
#         'name': 'Kolkata International Airport',
#         'position': {'latitude': 22.65473,
#          'longitude': 88.446716,
#          'country': {'name': 'India', 'code': 'IN', 'id': 102},
#          'region': {'city': 'Kolkata'}},
#         'visible': True},
#        'real': None},
#       'time': {'scheduled': {'departure': 1680159600, 'arrival': 1680176400},
#        'real': {'departure': None, 'arrival': None},
#        'estimated': {'departure': None, 'arrival': None},
#        'other': {'eta': None, 'duration': None}}}}]}},
#  'weather': {'metar': 'OTHH 300000Z 28008KT 230V320 CAVOK 21/12 Q1012 NOSIG',
#   'time': 1680134400,
#   'qnh': 1012,
#   'dewpoint': {'celsius': 12, 'fahrenheit': 54},
#   'humidity': 56,
#   'pressure': {'hg': 30, 'hpa': 1012},
#   'sky': {'condition': {'text': 'Clear'},
#    'visibility': {'km': 10000000, 'mi': 6, 'nmi': 5}},
#   'flight': {'category': None},
#   'wind': {'direction': {'degree': 280, 'text': 'From west'},
#    'speed': {'kmh': 14, 'kts': 8, 'mph': 9, 'text': 'Mod'}},
#   'temp': {'celsius': 21, 'fahrenheit': 70},
#   'elevation': {'m': 3, 'ft': 10},
#   'cached': 1680136385},
#  'aircraftCount': {'ground': 42, 'onGround': {'visible': 8, 'total': 41}},
#  'runways': [{'name': '16L',
#    'length': {'ft': 15912, 'm': 4850},
#    'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#   {'name': '16R',
#    'length': {'ft': 13944, 'm': 4250},
#    'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#   {'name': '34L',
#    'length': {'ft': 13944, 'm': 4250},
#    'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#   {'name': '34R',
#    'length': {'ft': 15912, 'm': 4850},
#    'surface': {'code': 'ASPH', 'name': 'Asphalt'}}]}

# %%
dict1.keys()
# Out:
# dict_keys(['details', 'flightdiary', 'schedule', 'weather', 'aircraftCount', 'runways'])

# %%
# Search for useful data
dict1['runways']
# Out:
# [{'name': '16L',
#   'length': {'ft': 15912, 'm': 4850},
#   'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#  {'name': '16R',
#   'length': {'ft': 13944, 'm': 4250},
#   'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#  {'name': '34L',
#   'length': {'ft': 13944, 'm': 4250},
#   'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#  {'name': '34R',
#   'length': {'ft': 15912, 'm': 4850},
#   'surface': {'code': 'ASPH', 'name': 'Asphalt'}}]

# %%
# Found significant data and store in variable flight_data
flight_data = dict1['schedule']['departures']['data']
flight_data
# Out:
# [{'flight': {'identification': {'id': None,
#     'row': 5341427706,
#     'number': {'default': 'QR8434', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '77X', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#      'timezone': {'name': 'Asia/Bangkok',
#       'offset': 25200,
#       'abbr': '+07',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Bangkok Suvarnabhumi Airport',
#      'position': {'latitude': 13.6811,
#       'longitude': 100.7472,
#       'country': {'name': 'Thailand', 'code': 'TH', 'id': 221},
#       'region': {'city': 'Bangkok'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680138300, 'arrival': 1680161100},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5343637775,
#     'number': {'default': 'QR8360', 'alternative': '9T8360'},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '74Y', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'HKG', 'icao': 'VHHH'},
#      'timezone': {'name': 'Asia/Hong_Kong',
#       'offset': 28800,
#       'abbr': 'HKT',
#       'abbrName': 'Hong Kong Time',
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Hong Kong International Airport',
#      'position': {'latitude': 22.309616,
#       'longitude': 113.916237,
#       'country': {'name': 'Hong Kong', 'code': 'HK', 'id': 99},
#       'region': {'city': 'Hong Kong'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680138600, 'arrival': 1680168600},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5344268274,
#     'number': {'default': 'QR1166', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['VA6208',
#      'WB1178',
#      'WY6470',
#      'AA8204',
#      'BA2327',
#      'CX9215',
#      'IB870',
#      'LA5624',
#      'MH4138']},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C81'}},
#     'destination': {'code': {'iata': 'RUH', 'icao': 'OERK'},
#      'timezone': {'name': 'Asia/Riyadh',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': 'T3', 'baggage': None, 'gate': None},
#      'name': 'Riyadh King Khalid International Airport',
#      'position': {'latitude': 24.95764,
#       'longitude': 46.698769,
#       'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#       'region': {'city': 'Riyadh'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680139800, 'arrival': 1680145200},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427024,
#     'number': {'default': 'QR1190', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['WY6482',
#      'MH4148',
#      'CX9308',
#      'IB902',
#      'BA2360',
#      'AA8263',
#      'VA6071']},
#    'status': {'live': False,
#     'text': 'Estimated dep 04:40',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680140400, 'local': 1680151200}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'A11'}},
#     'destination': {'code': {'iata': 'JED', 'icao': 'OEJN'},
#      'timezone': {'name': 'Asia/Riyadh',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': '1', 'baggage': None, 'gate': None},
#      'name': 'Jeddah King Abdulaziz International Airport',
#      'position': {'latitude': 21.67956,
#       'longitude': 39.156528,
#       'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#       'region': {'city': 'Jeddah'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680140400, 'arrival': 1680149700},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680140400, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5343637776,
#     'number': {'default': 'QR8111', 'alternative': None},
#     'callsign': 'QTR8111',
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 04:55',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680141300, 'local': 1680152100}}},
#    'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-F'},
#     'registration': 'A7-BFT',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A2E1',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Cargo',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'MXP', 'icao': 'LIMC'},
#      'timezone': {'name': 'Europe/Rome',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Milan Malpensa Airport',
#      'position': {'latitude': 45.6306,
#       'longitude': 8.728111,
#       'country': {'name': 'Italy', 'code': 'IT', 'id': 109},
#       'region': {'city': 'Milan'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680140700, 'arrival': 1680163200},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680141300, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427729,
#     'number': {'default': 'QR8696', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '77X', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'BLR', 'icao': 'VOBL'},
#      'timezone': {'name': 'Asia/Kolkata',
#       'offset': 19800,
#       'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Bengaluru Kempegowda International Airport',
#      'position': {'latitude': 13.198889,
#       'longitude': 77.705559,
#       'country': {'name': 'India', 'code': 'IN', 'id': 102},
#       'region': {'city': 'Bengaluru'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680143700, 'arrival': 1680158100},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5344453849,
#     'number': {'default': 'MH6124', 'alternative': None},
#     'callsign': 'MAS6124',
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 05:55',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680144900, 'local': 1680155700}}},
#    'aircraft': {'model': {'code': 'A332', 'text': 'Airbus A330-223F'},
#     'registration': '9M-MUA',
#     'country': {'id': 133,
#      'name': 'Malaysia',
#      'alpha2': 'MY',
#      'alpha3': 'MYS'},
#     'hex': '750263',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Malaysia Airlines',
#     'code': {'iata': 'MH', 'icao': 'MAS'},
#     'logo': 's3:MH_MAS.png'},
#    'airline': {'name': 'MASkargo',
#     'code': {'iata': 'MH', 'icao': 'MAS'},
#     'short': 'Malaysia Airlines'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'AMS', 'icao': 'EHAM'},
#      'timezone': {'name': 'Europe/Amsterdam',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Amsterdam Schiphol Airport',
#      'position': {'latitude': 52.308609,
#       'longitude': 4.763889,
#       'country': {'name': 'Netherlands', 'code': 'NL', 'id': 155},
#       'region': {'city': 'Amsterdam'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680144300, 'arrival': 1680169020},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680144900, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341438568,
#     'number': {'default': 'TK783', 'alternative': None},
#     'callsign': 'THY5TA',
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 06:05',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680145500, 'local': 1680156300}}},
#    'aircraft': {'model': {'code': 'A21N', 'text': 'Airbus A321-271NX'},
#     'registration': 'TC-LSU',
#     'country': {'id': 228, 'name': 'Turkey', 'alpha2': 'TR', 'alpha3': 'TUR'},
#     'hex': '4BB275',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Turkish Airlines',
#     'code': {'iata': 'TK', 'icao': 'THY'},
#     'logo': 's3:TK_THY.png'},
#    'airline': {'name': 'Turkish Airlines',
#     'code': {'iata': 'TK', 'icao': 'THY'},
#     'short': 'Turkish Airlines'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': '1', 'baggage': None, 'gate': 'B7'}},
#     'destination': {'code': {'iata': 'IST', 'icao': 'LTFM'},
#      'timezone': {'name': 'Europe/Istanbul',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Istanbul Airport',
#      'position': {'latitude': 41.267052,
#       'longitude': 28.729757,
#       'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#       'region': {'city': 'Istanbul'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680144900, 'arrival': 1680161100},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680145500, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427712,
#     'number': {'default': 'QR8511', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '77X', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'KWI', 'icao': 'OKKK'},
#      'timezone': {'name': 'Asia/Kuwait',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Kuwait International Airport',
#      'position': {'latitude': 29.226561,
#       'longitude': 47.968922,
#       'country': {'name': 'Kuwait', 'code': 'KW', 'id': 118},
#       'region': {'city': 'Kuwait City'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680145800, 'arrival': 1680151500},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5343637777,
#     'number': {'default': 'QR8482', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '77X', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'KWI', 'icao': 'OKKK'},
#      'timezone': {'name': 'Asia/Kuwait',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Kuwait International Airport',
#      'position': {'latitude': 29.226561,
#       'longitude': 47.968922,
#       'country': {'name': 'Kuwait', 'code': 'KW', 'id': 118},
#       'region': {'city': 'Kuwait City'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680146100, 'arrival': 1680151500},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341428431,
#     'number': {'default': 'RJ651', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['QR6100']},
#    'status': {'live': False,
#     'text': 'Estimated dep 06:35',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680147300, 'local': 1680158100}}},
#    'aircraft': {'model': {'code': '319', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Royal Jordanian',
#     'code': {'iata': 'RJ', 'icao': 'RJA'},
#     'short': 'Royal Jordanian'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'A1'}},
#     'destination': {'code': {'iata': 'AMM', 'icao': 'OJAI'},
#      'timezone': {'name': 'Asia/Amman',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': '120'},
#      'name': 'Amman Queen Alia International Airport',
#      'position': {'latitude': 31.722549,
#       'longitude': 35.99321,
#       'country': {'name': 'Jordan', 'code': 'JO', 'id': 113},
#       'region': {'city': 'Amman'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680147300, 'arrival': 1680157800},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680147300, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341425852,
#     'number': {'default': 'QR239', 'alternative': None},
#     'callsign': 'QTR4C',
#     'codeshare': ['CX9239', 'VA6093', 'UL3120', 'WY6319', 'MH9319', 'WB1037']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:15',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680149700, 'local': 1680160500}}},
#    'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-367(ER)'},
#     'registration': 'A7-BOB',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A373',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C82'}},
#     'destination': {'code': {'iata': 'IST', 'icao': 'LTFM'},
#      'timezone': {'name': 'Europe/Istanbul',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': 'I', 'baggage': '16', 'gate': None},
#      'name': 'Istanbul Airport',
#      'position': {'latitude': 41.267052,
#       'longitude': 28.729757,
#       'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#       'region': {'city': 'Istanbul'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680149700, 'arrival': 1680165900},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680149700, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426990,
#     'number': {'default': 'QR1178', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['IB868', 'VA6142', 'WY6476', 'BA2366', 'MH4142', 'CX9236']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:15',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680149700, 'local': 1680160500}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'A4'}},
#     'destination': {'code': {'iata': 'MED', 'icao': 'OEMA'},
#      'timezone': {'name': 'Asia/Riyadh',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Medina Prince Mohammad bin Abdulaziz Airport',
#      'position': {'latitude': 24.553419,
#       'longitude': 39.705059,
#       'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#       'region': {'city': 'Medina'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680149700, 'arrival': 1680158400},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680149700, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426536,
#     'number': {'default': 'QR773', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['CX9373', 'LA5261']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:30',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680150600, 'local': 1680161400}}},
#    'aircraft': {'model': {'code': '77W', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C23'}},
#     'destination': {'code': {'iata': 'GRU', 'icao': 'SBGR'},
#      'timezone': {'name': 'America/Sao_Paulo',
#       'offset': -10800,
#       'abbr': '-03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': '3', 'baggage': None, 'gate': None},
#      'name': 'Sao Paulo Guarulhos International Airport',
#      'position': {'latitude': -23.431999,
#       'longitude': -46.469501,
#       'country': {'name': 'Brazil', 'code': 'BR', 'id': 32},
#       'region': {'city': 'Sao Paulo'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680150600, 'arrival': 1680202500},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680150600, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427698,
#     'number': {'default': 'QR8253', 'alternative': '9T8253'},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Canceled',
#     'icon': 'red',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'canceled',
#       'type': 'departure',
#       'color': 'red',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '74Y', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'CDG', 'icao': 'LFPG'},
#      'timezone': {'name': 'Europe/Paris',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Paris Charles de Gaulle Airport',
#      'position': {'latitude': 49.012516,
#       'longitude': 2.555752,
#       'country': {'name': 'France', 'code': 'FR', 'id': 76},
#       'region': {'city': 'Paris'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680150600, 'arrival': 1680172200},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341425771,
#     'number': {'default': 'QR175', 'alternative': None},
#     'callsign': 'QTR61W',
#     'codeshare': ['MH9265', 'AY6665', 'WB1029', 'VA6062', 'UL3485', 'WY6309']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:35',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680150900, 'local': 1680161700}}},
#    'aircraft': {'model': {'code': 'B789', 'text': 'Boeing 787-9 Dreamliner'},
#     'registration': 'A7-BHO',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A2F2',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'A11'}},
#     'destination': {'code': {'iata': 'OSL', 'icao': 'ENGM'},
#      'timezone': {'name': 'Europe/Oslo',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Oslo Gardermoen Airport',
#      'position': {'latitude': 60.193909,
#       'longitude': 11.10036,
#       'country': {'name': 'Norway', 'code': 'NO', 'id': 165},
#       'region': {'city': 'Oslo'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680150900, 'arrival': 1680176400},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680150900, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427041,
#     'number': {'default': 'QR1206', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['CX9218', 'AA8296', 'VA6204', 'IB2415']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:35',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680150900, 'local': 1680161700}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C83'}},
#     'destination': {'code': {'iata': 'TIF', 'icao': 'OETF'},
#      'timezone': {'name': 'Asia/Riyadh',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Taif Airport',
#      'position': {'latitude': 21.48341,
#       'longitude': 40.544331,
#       'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#       'region': {'city': 'Taif'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680150900, 'arrival': 1680159600},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680150900, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341425817,
#     'number': {'default': 'QR203', 'alternative': None},
#     'callsign': 'QTR45B',
#     'codeshare': ['MH9279', 'CX9231', 'WY6124', 'VA6036']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:40',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151200, 'local': 1680162000}}},
#    'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-2DZ(LR)'},
#     'registration': 'A7-BBE',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A075',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C36'}},
#     'destination': {'code': {'iata': 'ATH', 'icao': 'LGAV'},
#      'timezone': {'name': 'Europe/Athens',
#       'offset': 10800,
#       'abbr': 'EEST',
#       'abbrName': 'Eastern European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Athens Eleftherios Venizelos',
#      'position': {'latitude': 37.936352,
#       'longitude': 23.94446,
#       'country': {'name': 'Greece', 'code': 'GR', 'id': 86},
#       'region': {'city': 'Athens'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151200, 'arrival': 1680168600},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680151200, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426053,
#     'number': {'default': 'QR482', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['WY6185']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:40',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151200, 'local': 1680162000}}},
#    'aircraft': {'model': {'code': '332', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C43'}},
#     'destination': {'code': {'iata': 'IKA', 'icao': 'OIIE'},
#      'timezone': {'name': 'Asia/Tehran',
#       'offset': 12600,
#       'abbr': '+0330',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Tehran Imam Khomeini International Airport',
#      'position': {'latitude': 35.416111,
#       'longitude': 51.152222,
#       'country': {'name': 'Iran', 'code': 'IR', 'id': 104},
#       'region': {'city': 'Tehran'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151200, 'arrival': 1680159000},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680151200, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426872,
#     'number': {'default': 'QR1038', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:40',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151200, 'local': 1680162000}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C81'}},
#     'destination': {'code': {'iata': 'SHJ', 'icao': 'OMSJ'},
#      'timezone': {'name': 'Asia/Dubai',
#       'offset': 14400,
#       'abbr': '+04',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': '1', 'gate': None},
#      'name': 'Sharjah International Airport',
#      'position': {'latitude': 25.328569,
#       'longitude': 55.517151,
#       'country': {'name': 'United Arab Emirates', 'code': 'AE', 'id': 234},
#       'region': {'city': 'Sharjah'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151200, 'arrival': 1680155400},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680151200, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341425558,
#     'number': {'default': 'QR39', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['UL3539', 'MH9215', 'WY6289', 'VA6024']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:45',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151500, 'local': 1680162300}}},
#    'aircraft': {'model': {'code': '77W', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'A10'}},
#     'destination': {'code': {'iata': 'CDG', 'icao': 'LFPG'},
#      'timezone': {'name': 'Europe/Paris',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': '1', 'baggage': None, 'gate': None},
#      'name': 'Paris Charles de Gaulle Airport',
#      'position': {'latitude': 49.012516,
#       'longitude': 2.555752,
#       'country': {'name': 'France', 'code': 'FR', 'id': 76},
#       'region': {'city': 'Paris'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680177300},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680151500, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426005,
#     'number': {'default': 'QR416', 'alternative': None},
#     'callsign': 'QTR62R',
#     'codeshare': ['ME4435', 'AT5804', 'WY6138', 'VA6055', 'LA7410']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:45',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151500, 'local': 1680162300}}},
#    'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': 'A7-AHE',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A08E',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C80'}},
#     'destination': {'code': {'iata': 'BEY', 'icao': 'OLBA'},
#      'timezone': {'name': 'Asia/Beirut',
#       'offset': 10800,
#       'abbr': 'EEST',
#       'abbrName': 'Eastern European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Beirut Rafic Hariri International Airport',
#      'position': {'latitude': 33.82093,
#       'longitude': 35.48838,
#       'country': {'name': 'Lebanon', 'code': 'LB', 'id': 122},
#       'region': {'city': 'Beirut'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680161700},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680151500, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426527,
#     'number': {'default': 'QR763', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['MH9295', 'UL3176']},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '77W', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C18'}},
#     'destination': {'code': {'iata': 'YUL', 'icao': 'CYUL'},
#      'timezone': {'name': 'America/Montreal',
#       'offset': -14400,
#       'abbr': 'EDT',
#       'abbrName': 'Eastern Daylight Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Montreal Pierre Elliott Trudeau Airport',
#      'position': {'latitude': 45.470551,
#       'longitude': -73.740799,
#       'country': {'name': 'Canada', 'code': 'CA', 'id': 40},
#       'region': {'city': 'Montreal'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680199200},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427288,
#     'number': {'default': 'QR1463', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'MGQ', 'icao': 'HCMM'},
#      'timezone': {'name': 'Africa/Mogadishu',
#       'offset': 10800,
#       'abbr': 'EAT',
#       'abbrName': 'East Africa Time',
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Mogadishu Aden Adde International Airport',
#      'position': {'latitude': 2.014444,
#       'longitude': 45.304722,
#       'country': {'name': 'Somalia', 'code': 'SO', 'id': 204},
#       'region': {'city': 'Mogadishu'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680168300},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427299,
#     'number': {'default': 'QR1476', 'alternative': None},
#     'callsign': None,
#     'codeshare': ['JL5592',
#      'AT5770',
#      'IB2480',
#      'AS5871',
#      'AY6677',
#      'BA6363',
#      'AA8180',
#      'LA5316']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:45',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151500, 'local': 1680162300}}},
#    'aircraft': {'model': {'code': '332', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C62'}},
#     'destination': {'code': {'iata': 'DAR', 'icao': 'HTDA'},
#      'timezone': {'name': 'Africa/Dar_es_Salaam',
#       'offset': 10800,
#       'abbr': 'EAT',
#       'abbrName': 'East Africa Time',
#       'isDst': False},
#      'info': {'terminal': '3', 'baggage': None, 'gate': None},
#      'name': 'Dar-es-Salaam Julius Nyerere International Airport',
#      'position': {'latitude': -6.87811,
#       'longitude': 39.202621,
#       'country': {'name': 'Tanzania', 'code': 'TZ', 'id': 220},
#       'region': {'city': 'Dar-es-Salaam'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151500, 'arrival': 1680173100},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680151500, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341425753,
#     'number': {'default': 'QR149', 'alternative': None},
#     'callsign': 'QTR149',
#     'codeshare': ['UL3421', 'VA6083', 'IB7902', 'MH9249', 'WY6307', 'LA5315']},
#    'status': {'live': False,
#     'text': 'Estimated dep 07:50',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680151800, 'local': 1680162600}}},
#    'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-2DZ(LR)'},
#     'registration': 'A7-BBH',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A07E',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'A9'}},
#     'destination': {'code': {'iata': 'MAD', 'icao': 'LEMD'},
#      'timezone': {'name': 'Europe/Madrid',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': '4S', 'baggage': '06', 'gate': None},
#      'name': 'Madrid Barajas Airport',
#      'position': {'latitude': 40.488701,
#       'longitude': -3.57,
#       'country': {'name': 'Spain', 'code': 'ES', 'id': 209},
#       'region': {'city': 'Madrid'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680151800, 'arrival': 1680179700},
# ...
#      'eventTime': {'utc': 1680155100, 'local': 1680165900}}},
#    'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-F'},
#     'registration': 'A7-BFU',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A2E2',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Cargo',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'ZAZ', 'icao': 'LEZG'},
#      'timezone': {'name': 'Europe/Madrid',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Zaragoza Airport',
#      'position': {'latitude': 41.666241,
#       'longitude': -1.04155,
#       'country': {'name': 'Spain', 'code': 'ES', 'id': 209},
#       'region': {'city': 'Zaragoza'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680156300, 'arrival': 1680183000},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680155100, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341426214,
#     'number': {'default': 'QR646', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '333', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'B7'}},
#     'destination': {'code': {'iata': 'KTM', 'icao': 'VNKT'},
#      'timezone': {'name': 'Asia/Kathmandu',
#       'offset': 20700,
#       'abbr': '+0545',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': 'I', 'baggage': None, 'gate': None},
#      'name': 'Kathmandu Tribhuvan International Airport',
#      'position': {'latitude': 27.696581,
#       'longitude': 85.3591,
#       'country': {'name': 'Nepal', 'code': 'NP', 'id': 154},
#       'region': {'city': 'Kathmandu'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680156900, 'arrival': 1680174000},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5343637808,
#     'number': {'default': 'QR8062', 'alternative': None},
#     'callsign': 'QTR8062',
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 09:25',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680157500, 'local': 1680168300}}},
#    'aircraft': {'model': {'code': 'B77L', 'text': 'Boeing 777-FDZ'},
#     'registration': 'A7-BFO',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A1EC',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Cargo',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'MAD', 'icao': 'LEMD'},
#      'timezone': {'name': 'Europe/Madrid',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Madrid Barajas Airport',
#      'position': {'latitude': 40.488701,
#       'longitude': -3.57,
#       'country': {'name': 'Spain', 'code': 'ES', 'id': 209},
#       'region': {'city': 'Madrid'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680156900, 'arrival': 1680184500},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680157500, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427721,
#     'number': {'default': 'QR8572', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Canceled',
#     'icon': 'red',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'canceled',
#       'type': 'departure',
#       'color': 'red',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '74N', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'JED', 'icao': 'OEJN'},
#      'timezone': {'name': 'Asia/Riyadh',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Jeddah King Abdulaziz International Airport',
#      'position': {'latitude': 21.67956,
#       'longitude': 39.156528,
#       'country': {'name': 'Saudi Arabia', 'code': 'SA', 'id': 194},
#       'region': {'city': 'Jeddah'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680157200, 'arrival': 1680166800},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5344274334,
#     'number': {'default': 'QR634', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '333', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C84'}},
#     'destination': {'code': {'iata': 'DAC', 'icao': 'VGHS'},
#      'timezone': {'name': 'Asia/Dhaka',
#       'offset': 21600,
#       'abbr': '+06',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Dhaka Shahjalal International Airport',
#      'position': {'latitude': 23.84333,
#       'longitude': 90.397781,
#       'country': {'name': 'Bangladesh', 'code': 'BD', 'id': 19},
#       'region': {'city': 'Dhaka'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680158100, 'arrival': 1680178500},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341425787,
#     'number': {'default': 'QR183', 'alternative': None},
#     'callsign': 'QTR53L',
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 09:45',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680158700, 'local': 1680169500}}},
#    'aircraft': {'model': {'code': 'B788', 'text': 'Boeing 787-8 Dreamliner'},
#     'registration': 'A7-BCX',
#     'country': {'id': 179, 'name': 'Qatar', 'alpha2': 'QA', 'alpha3': 'QAT'},
#     'hex': '06A0BC',
#     'restricted': False,
#     'serialNo': None,
#     'age': {'availability': True},
#     'availability': {'serialNo': True, 'age': True}},
#    'owner': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'logo': 's3:QR_QTR.png'},
#    'airline': {'name': 'Qatar Airways (25 Years of Excellence Sticker)',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'C86'}},
#     'destination': {'code': {'iata': 'VIE', 'icao': 'LOWW'},
#      'timezone': {'name': 'Europe/Vienna',
#       'offset': 7200,
#       'abbr': 'CEST',
#       'abbrName': 'Central European Summer Time',
#       'isDst': True},
#      'info': {'terminal': '3', 'baggage': None, 'gate': None},
#      'name': 'Vienna International Airport',
#      'position': {'latitude': 48.110271,
#       'longitude': 16.569719,
#       'country': {'name': 'Austria', 'code': 'AT', 'id': 15},
#       'region': {'city': 'Vienna'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680158700, 'arrival': 1680179700},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680158700, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341376983,
#     'number': {'default': 'G9136', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 09:55',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680159300, 'local': 1680170100}}},
#    'aircraft': {'model': {'code': '320', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Air Arabia',
#     'code': {'iata': 'G9', 'icao': 'ABY'},
#     'short': 'Air Arabia'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'B10'}},
#     'destination': {'code': {'iata': 'SHJ', 'icao': 'OMSJ'},
#      'timezone': {'name': 'Asia/Dubai',
#       'offset': 14400,
#       'abbr': '+04',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': '2', 'gate': None},
#      'name': 'Sharjah International Airport',
#      'position': {'latitude': 25.328569,
#       'longitude': 55.517151,
#       'country': {'name': 'United Arab Emirates', 'code': 'AE', 'id': 234},
#       'region': {'city': 'Sharjah'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680159300, 'arrival': 1680162900},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680159300, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341366446,
#     'number': {'default': 'FZ2', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Estimated dep 10:00',
#     'icon': 'green',
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'estimated',
#       'type': 'departure',
#       'color': 'green',
#       'diverted': None},
#      'eventTime': {'utc': 1680159600, 'local': 1680170400}}},
#    'aircraft': {'model': {'code': '7M8', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'FlyDubai',
#     'code': {'iata': 'FZ', 'icao': 'FDB'},
#     'short': 'FlyDubai'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': 'B5'}},
#     'destination': {'code': {'iata': 'DXB', 'icao': 'OMDB'},
#      'timezone': {'name': 'Asia/Dubai',
#       'offset': 14400,
#       'abbr': '+04',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': '2', 'baggage': '1', 'gate': None},
#      'name': 'Dubai International Airport',
#      'position': {'latitude': 25.252769,
#       'longitude': 55.364441,
#       'country': {'name': 'United Arab Emirates', 'code': 'AE', 'id': 234},
#       'region': {'city': 'Dubai'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680159600, 'arrival': 1680164100},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': 1680159600, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}},
#  {'flight': {'identification': {'id': None,
#     'row': 5341427671,
#     'number': {'default': 'QR8094', 'alternative': None},
#     'callsign': None,
#     'codeshare': None},
#    'status': {'live': False,
#     'text': 'Scheduled',
#     'icon': None,
#     'estimated': None,
#     'ambiguous': False,
#     'generic': {'status': {'text': 'scheduled',
#       'type': 'departure',
#       'color': 'gray',
#       'diverted': None},
#      'eventTime': {'utc': None, 'local': None}}},
#    'aircraft': {'model': {'code': '77X', 'text': ''},
#     'hex': '',
#     'registration': '',
#     'serialNo': '',
#     'images': None},
#    'owner': None,
#    'airline': {'name': 'Qatar Airways',
#     'code': {'iata': 'QR', 'icao': 'QTR'},
#     'short': 'Qatar Airways'},
#    'airport': {'origin': {'timezone': {'name': 'Asia/Qatar',
#       'offset': 10800,
#       'abbr': '+03',
#       'abbrName': None,
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None}},
#     'destination': {'code': {'iata': 'CCU', 'icao': 'VECC'},
#      'timezone': {'name': 'Asia/Kolkata',
#       'offset': 19800,
#       'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': False},
#      'info': {'terminal': None, 'baggage': None, 'gate': None},
#      'name': 'Kolkata International Airport',
#      'position': {'latitude': 22.65473,
#       'longitude': 88.446716,
#       'country': {'name': 'India', 'code': 'IN', 'id': 102},
#       'region': {'city': 'Kolkata'}},
#      'visible': True},
#     'real': None},
#    'time': {'scheduled': {'departure': 1680159600, 'arrival': 1680176400},
#     'real': {'departure': None, 'arrival': None},
#     'estimated': {'departure': None, 'arrival': None},
#     'other': {'eta': None, 'duration': None}}}}]

# %%
# convert nested dictionary into a flat dictionary
def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)
l = []
# append to new list, covert to pandas dataframe
for i in flight_data:
    l.append(flatten(i))
df = pd.DataFrame(l)
df
# Out:
#    flight_identification_id  flight_identification_row  \
# 0                      None                 5341427706
# 1                      None                 5343637775
# 2                      None                 5344268274
# 3                      None                 5341427024
# 4                      None                 5343637776
# ..                      ...                        ...
# 95                     None                 5344274334
# 96                     None                 5341425787
# 97                     None                 5341376983
# 98                     None                 5341366446
# 99                     None                 5341427671
#
#    flight_identification_number_default  \
# 0                                QR8434
# 1                                QR8360
# 2                                QR1166
# 3                                QR1190
# 4                                QR8111
# ..                                  ...
# 95                                QR634
# 96                                QR183
# 97                                G9136
# 98                                  FZ2
# 99                               QR8094
#
#    flight_identification_number_alternative flight_identification_callsign  \
# 0                                      None                           None
# 1                                    9T8360                           None
# 2                                      None                           None
# 3                                      None                           None
# 4                                      None                        QTR8111
# ..                                      ...                            ...
# 95                                     None                           None
# 96                                     None                         QTR53L
# 97                                     None                           None
# 98                                     None                           None
# 99                                     None                           None
#
#                       flight_identification_codeshare  flight_status_live  \
# 0                                                None               False
# 1                                                None               False
# 2   [VA6208, WB1178, WY6470, AA8204, BA2327, CX921...               False
# 3   [WY6482, MH4148, CX9308, IB902, BA2360, AA8263...               False
# 4                                                None               False
# ..                                                ...                 ...
# 95                                               None               False
# 96                                               None               False
# 97                                               None               False
# 98                                               None               False
# 99                                               None               False
#
#      flight_status_text flight_status_icon flight_status_estimated  ...  \
# 0             Scheduled               None                    None  ...
# 1             Scheduled               None                    None  ...
# 2             Scheduled               None                    None  ...
# 3   Estimated dep 04:40              green                    None  ...
# 4   Estimated dep 04:55              green                    None  ...
# ..                  ...                ...                     ...  ...
# 95            Scheduled               None                    None  ...
# 96  Estimated dep 09:45              green                    None  ...
# 97  Estimated dep 09:55              green                    None  ...
# 98  Estimated dep 10:00              green                    None  ...
# 99            Scheduled               None                    None  ...
#
#     flight_aircraft_country_alpha2 flight_aircraft_country_alpha3  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                               QA                            QAT
# ..                             ...                            ...
# 95                             NaN                            NaN
# 96                              QA                            QAT
# 97                             NaN                            NaN
# 98                             NaN                            NaN
# 99                             NaN                            NaN
#
#    flight_aircraft_restricted flight_aircraft_age_availability  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                       False                             True
# ..                        ...                              ...
# 95                        NaN                              NaN
# 96                      False                             True
# 97                        NaN                              NaN
# 98                        NaN                              NaN
# 99                        NaN                              NaN
#
#    flight_aircraft_availability_serialNo  flight_aircraft_availability_age  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                   True                              True
# ..                                   ...                               ...
# 95                                   NaN                               NaN
# 96                                  True                              True
# 97                                   NaN                               NaN
# 98                                   NaN                               NaN
# 99                                   NaN                               NaN
#
#     flight_owner_name flight_owner_code_iata flight_owner_code_icao  \
# 0                 NaN                    NaN                    NaN
# 1                 NaN                    NaN                    NaN
# 2                 NaN                    NaN                    NaN
# 3                 NaN                    NaN                    NaN
# 4       Qatar Airways                     QR                    QTR
# ..                ...                    ...                    ...
# 95                NaN                    NaN                    NaN
# 96      Qatar Airways                     QR                    QTR
# 97                NaN                    NaN                    NaN
# 98                NaN                    NaN                    NaN
# 99                NaN                    NaN                    NaN
#
#    flight_owner_logo
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4      s3:QR_QTR.png
# ..               ...
# 95               NaN
# 96     s3:QR_QTR.png
# 97               NaN
# 98               NaN
# 99               NaN
#
# [100 rows x 75 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Check values for cleaning
df.count()
# Out:
# flight_identification_id                      0
# flight_identification_row                   100
# flight_identification_number_default        100
# flight_identification_number_alternative      3
# flight_identification_callsign               45
#                                            ...
# flight_aircraft_availability_age             38
# flight_owner_name                            38
# flight_owner_code_iata                       38
# flight_owner_code_icao                       38
# flight_owner_logo                            34
# Length: 75, dtype: int64

# %%
# extract rows which are null
x = df.isnull().sum()
null_list = []
for index, value in x.items():
    if value == 100:
        null_list.append(index)
        print(index,value)
# Out:
# flight_identification_id 100
# flight_status_estimated 100
# flight_status_generic_status_diverted 100
# flight_aircraft_images 100
# flight_owner 100
# flight_airport_origin_timezone_abbrName 100
# flight_airport_origin_info_baggage 100
# flight_airport_real 100
# flight_time_real_departure 100
# flight_time_real_arrival 100
# flight_time_estimated_arrival 100
# flight_time_other_eta 100
# flight_time_other_duration 100

# %%
# Aggregate list of null columns to be used in drop
null_list
# Out:
# ['flight_identification_id',
#  'flight_status_estimated',
#  'flight_status_generic_status_diverted',
#  'flight_aircraft_images',
#  'flight_owner',
#  'flight_airport_origin_timezone_abbrName',
#  'flight_airport_origin_info_baggage',
#  'flight_airport_real',
#  'flight_time_real_departure',
#  'flight_time_real_arrival',
#  'flight_time_estimated_arrival',
#  'flight_time_other_eta',
#  'flight_time_other_duration']

# %%
df = df.drop(columns=['flight_identification_id',
 'flight_status_estimated',
 'flight_status_generic_status_diverted',
 'flight_aircraft_images',
 'flight_owner',
 'flight_airport_origin_timezone_abbrName',
 'flight_airport_origin_info_baggage',
 'flight_airport_real',
 'flight_time_real_departure',
 'flight_time_real_arrival',
 'flight_time_estimated_arrival',
 'flight_time_other_eta',
 'flight_time_other_duration'])

# %%
df.head()
# Out:
#    flight_identification_row flight_identification_number_default  \
# 0                 5341427706                               QR8434
# 1                 5343637775                               QR8360
# 2                 5344268274                               QR1166
# 3                 5341427024                               QR1190
# 4                 5343637776                               QR8111
#
#   flight_identification_number_alternative flight_identification_callsign  \
# 0                                     None                           None
# 1                                   9T8360                           None
# 2                                     None                           None
# 3                                     None                           None
# 4                                     None                        QTR8111
#
#                      flight_identification_codeshare  flight_status_live  \
# 0                                               None               False
# 1                                               None               False
# 2  [VA6208, WB1178, WY6470, AA8204, BA2327, CX921...               False
# 3  [WY6482, MH4148, CX9308, IB902, BA2360, AA8263...               False
# 4                                               None               False
#
#     flight_status_text flight_status_icon  flight_status_ambiguous  \
# 0            Scheduled               None                    False
# 1            Scheduled               None                    False
# 2            Scheduled               None                    False
# 3  Estimated dep 04:40              green                    False
# 4  Estimated dep 04:55              green                    False
#
#   flight_status_generic_status_text  ... flight_aircraft_country_alpha2  \
# 0                         scheduled  ...                            NaN
# 1                         scheduled  ...                            NaN
# 2                         scheduled  ...                            NaN
# 3                         estimated  ...                            NaN
# 4                         estimated  ...                             QA
#
#   flight_aircraft_country_alpha3  flight_aircraft_restricted  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            QAT                       False
#
#    flight_aircraft_age_availability flight_aircraft_availability_serialNo  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
# 2                               NaN                                   NaN
# 3                               NaN                                   NaN
# 4                              True                                  True
#
#   flight_aircraft_availability_age flight_owner_name flight_owner_code_iata  \
# 0                              NaN               NaN                    NaN
# 1                              NaN               NaN                    NaN
# 2                              NaN               NaN                    NaN
# 3                              NaN               NaN                    NaN
# 4                             True     Qatar Airways                     QR
#
#   flight_owner_code_icao flight_owner_logo
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    QTR     s3:QR_QTR.png
#
# [5 rows x 62 columns]

# %%
# Here there are more values which aren't completely null but still provide no use
df.isnull().sum()
# Out:
# flight_identification_row                    0
# flight_identification_number_default         0
# flight_identification_number_alternative    97
# flight_identification_callsign              55
# flight_identification_codeshare             77
#                                             ..
# flight_aircraft_availability_age            62
# flight_owner_name                           62
# flight_owner_code_iata                      62
# flight_owner_code_icao                      62
# flight_owner_logo                           66
# Length: 62, dtype: int64

# %%
# Decided to get list of columns to instead pull neccessary information rather than delete unncessary data
columns_list = df.columns.tolist()
columns_list
# Out:
# ['flight_identification_row',
#  'flight_identification_number_default',
#  'flight_identification_number_alternative',
#  'flight_identification_callsign',
#  'flight_identification_codeshare',
#  'flight_status_live',
#  'flight_status_text',
#  'flight_status_icon',
#  'flight_status_ambiguous',
#  'flight_status_generic_status_text',
#  'flight_status_generic_status_type',
#  'flight_status_generic_status_color',
#  'flight_status_generic_eventTime_utc',
#  'flight_status_generic_eventTime_local',
#  'flight_aircraft_model_code',
#  'flight_aircraft_model_text',
#  'flight_aircraft_hex',
#  'flight_aircraft_registration',
#  'flight_aircraft_serialNo',
#  'flight_airline_name',
#  'flight_airline_code_iata',
#  'flight_airline_code_icao',
#  'flight_airline_short',
#  'flight_airport_origin_timezone_name',
#  'flight_airport_origin_timezone_offset',
#  'flight_airport_origin_timezone_abbr',
#  'flight_airport_origin_timezone_isDst',
#  'flight_airport_origin_info_terminal',
#  'flight_airport_origin_info_gate',
#  'flight_airport_destination_code_iata',
#  'flight_airport_destination_code_icao',
#  'flight_airport_destination_timezone_name',
#  'flight_airport_destination_timezone_offset',
#  'flight_airport_destination_timezone_abbr',
#  'flight_airport_destination_timezone_abbrName',
#  'flight_airport_destination_timezone_isDst',
#  'flight_airport_destination_info_terminal',
#  'flight_airport_destination_info_baggage',
#  'flight_airport_destination_info_gate',
#  'flight_airport_destination_name',
#  'flight_airport_destination_position_latitude',
#  'flight_airport_destination_position_longitude',
#  'flight_airport_destination_position_country_name',
#  'flight_airport_destination_position_country_code',
#  'flight_airport_destination_position_country_id',
#  'flight_airport_destination_position_region_city',
#  'flight_airport_destination_visible',
#  'flight_time_scheduled_departure',
#  'flight_time_scheduled_arrival',
#  'flight_time_estimated_departure',
#  'flight_aircraft_country_id',
#  'flight_aircraft_country_name',
#  'flight_aircraft_country_alpha2',
#  'flight_aircraft_country_alpha3',
#  'flight_aircraft_restricted',
#  'flight_aircraft_age_availability',
#  'flight_aircraft_availability_serialNo',
#  'flight_aircraft_availability_age',
#  'flight_owner_name',
#  'flight_owner_code_iata',
#  'flight_owner_code_icao',
#  'flight_owner_logo']

# %%
# Create dataframe with desired columns
df_new = df.loc[:,['flight_airline_code_icao', 
                   'flight_identification_number_default',
                   'flight_status_text',
                   'flight_airport_destination_timezone_name',
                   'flight_airport_destination_timezone_abbr',
                   'flight_airport_destination_name',
                   'flight_airport_destination_position_country_name',
                   'flight_airport_destination_position_region_city',
                   'flight_time_scheduled_departure',
                   'flight_time_scheduled_arrival',
                  ]]
df_new.head()
# Out:
#   flight_airline_code_icao flight_identification_number_default  \
# 0                      QTR                               QR8434
# 1                      QTR                               QR8360
# 2                      QTR                               QR1166
# 3                      QTR                               QR1190
# 4                      QTR                               QR8111
#
#     flight_status_text flight_airport_destination_timezone_name  \
# 0            Scheduled                             Asia/Bangkok
# 1            Scheduled                           Asia/Hong_Kong
# 2            Scheduled                              Asia/Riyadh
# 3  Estimated dep 04:40                              Asia/Riyadh
# 4  Estimated dep 04:55                              Europe/Rome
#
#   flight_airport_destination_timezone_abbr  \
# 0                                      +07
# 1                                      HKT
# 2                                      +03
# 3                                      +03
# 4                                     CEST
#
#                flight_airport_destination_name  \
# 0                 Bangkok Suvarnabhumi Airport
# 1              Hong Kong International Airport
# 2     Riyadh King Khalid International Airport
# 3  Jeddah King Abdulaziz International Airport
# 4                       Milan Malpensa Airport
#
#   flight_airport_destination_position_country_name  \
# 0                                         Thailand
# 1                                        Hong Kong
# 2                                     Saudi Arabia
# 3                                     Saudi Arabia
# 4                                            Italy
#
#   flight_airport_destination_position_region_city  \
# 0                                         Bangkok
# 1                                       Hong Kong
# 2                                          Riyadh
# 3                                          Jeddah
# 4                                           Milan
#
#    flight_time_scheduled_departure  flight_time_scheduled_arrival
# 0                       1680138300                     1680161100
# 1                       1680138600                     1680168600
# 2                       1680139800                     1680145200
# 3                       1680140400                     1680149700
# 4                       1680140700                     1680163200

# %%
# View destination timezones needed for time conversions
print(df_new['flight_airport_destination_timezone_name'].unique())
# Out:
# ['Asia/Bangkok' 'Asia/Hong_Kong' 'Asia/Riyadh' 'Europe/Rome'
#  'Asia/Kolkata' 'Europe/Amsterdam' 'Europe/Istanbul' 'Asia/Kuwait'
#  'Asia/Amman' 'America/Sao_Paulo' 'Europe/Paris' 'Europe/Oslo'
#  'Europe/Athens' 'Asia/Tehran' 'Asia/Dubai' 'Asia/Beirut'
#  'America/Montreal' 'Africa/Mogadishu' 'Africa/Dar_es_Salaam'
#  'Europe/Madrid' 'America/Chicago' 'America/Los_Angeles'
#  'America/New_York' 'Asia/Manila' 'Africa/Lagos' 'Asia/Muscat'
#  'Europe/London' 'Asia/Makassar' 'Europe/Dublin' 'Europe/Berlin'
#  'Asia/Nicosia' 'Europe/Luxembourg' 'Europe/Copenhagen'
#  'Asia/Kuala_Lumpur' 'Europe/Prague' 'Africa/Johannesburg' 'Asia/Dhaka'
#  'Europe/Helsinki' 'Europe/Stockholm' 'Europe/Zurich' 'Europe/Warsaw'
#  'Europe/Bucharest' 'Asia/Singapore' 'Africa/Cairo' 'Europe/Budapest'
#  'Asia/Jakarta' 'Asia/Baghdad' 'Africa/Kampala' 'Asia/Colombo'
#  'Africa/Tunis' 'Asia/Seoul' 'Asia/Baku' 'Indian/Maldives'
#  'Asia/Kathmandu' 'Europe/Vienna']

# %%
# Convert the 'flight_time_scheduled_departure' column from Unix time to a datetime object
df_new['flight_time_scheduled_departure'] = pd.to_datetime(df_new['flight_time_scheduled_departure'], unit='s')

# Create a new column 'scheduled_departure_local_time' to store the scheduled departure time in the destination airport's timezone
df_new['scheduled_departure_local_time'] = None

# Iterate through the unique timezones in the 'flight_airport_destination_timezone_name' column
for timezone in df_new['flight_airport_destination_timezone_name'].unique():
    # Use the pandas tz_localize() function to set the timezone of the 'scheduled_departure_local_time' column to the destination airport's timezone
    df_new.loc[df_new['flight_airport_destination_timezone_name'] == timezone, 'scheduled_departure_local_time'] = pd.to_datetime(df_new.loc[df_new['flight_airport_destination_timezone_name'] == timezone, 'flight_time_scheduled_departure'], unit='s').dt.tz_localize(timezone)

df_new.head()
# Out:
#   flight_airline_code_icao flight_identification_number_default  \
# 0                      QTR                               QR8434
# 1                      QTR                               QR8360
# 2                      QTR                               QR1166
# 3                      QTR                               QR1190
# 4                      QTR                               QR8111
#
#     flight_status_text flight_airport_destination_timezone_name  \
# 0            Scheduled                             Asia/Bangkok
# 1            Scheduled                           Asia/Hong_Kong
# 2            Scheduled                              Asia/Riyadh
# 3  Estimated dep 04:40                              Asia/Riyadh
# 4  Estimated dep 04:55                              Europe/Rome
#
#   flight_airport_destination_timezone_abbr  \
# 0                                      +07
# 1                                      HKT
# 2                                      +03
# 3                                      +03
# 4                                     CEST
#
#                flight_airport_destination_name  \
# 0                 Bangkok Suvarnabhumi Airport
# 1              Hong Kong International Airport
# 2     Riyadh King Khalid International Airport
# 3  Jeddah King Abdulaziz International Airport
# 4                       Milan Malpensa Airport
#
#   flight_airport_destination_position_country_name  \
# 0                                         Thailand
# 1                                        Hong Kong
# 2                                     Saudi Arabia
# 3                                     Saudi Arabia
# 4                                            Italy
#
#   flight_airport_destination_position_region_city  \
# 0                                         Bangkok
# 1                                       Hong Kong
# 2                                          Riyadh
# 3                                          Jeddah
# 4                                           Milan
#
#   flight_time_scheduled_departure  flight_time_scheduled_arrival  \
# 0             2023-03-30 01:05:00                     1680161100
# 1             2023-03-30 01:10:00                     1680168600
# 2             2023-03-30 01:30:00                     1680145200
# 3             2023-03-30 01:40:00                     1680149700
# 4             2023-03-30 01:45:00                     1680163200
#
#   scheduled_departure_local_time
# 0      2023-03-30 01:05:00+07:00
# 1      2023-03-30 01:10:00+08:00
# 2      2023-03-30 01:30:00+03:00
# 3      2023-03-30 01:40:00+03:00
# 4      2023-03-30 01:45:00+02:00

# %%
# Repeat for scheduled_arrival
df_new['flight_time_scheduled_arrival'] = pd.to_datetime(df_new['flight_time_scheduled_arrival'], unit='s')

df_new['scheduled_arrival_local_time'] = None

for timezone in df_new['flight_airport_destination_timezone_name'].unique():

    df_new.loc[df_new['flight_airport_destination_timezone_name'] == timezone, 'scheduled_arrival_local_time'] = pd.to_datetime(df_new.loc[df_new['flight_airport_destination_timezone_name'] == timezone, 'flight_time_scheduled_arrival'], unit='s').dt.tz_localize(timezone)

df_new.head()
# Out:
#   flight_airline_code_icao flight_identification_number_default  \
# 0                      QTR                               QR8434
# 1                      QTR                               QR8360
# 2                      QTR                               QR1166
# 3                      QTR                               QR1190
# 4                      QTR                               QR8111
#
#     flight_status_text flight_airport_destination_timezone_name  \
# 0            Scheduled                             Asia/Bangkok
# 1            Scheduled                           Asia/Hong_Kong
# 2            Scheduled                              Asia/Riyadh
# 3  Estimated dep 04:40                              Asia/Riyadh
# 4  Estimated dep 04:55                              Europe/Rome
#
#   flight_airport_destination_timezone_abbr  \
# 0                                      +07
# 1                                      HKT
# 2                                      +03
# 3                                      +03
# 4                                     CEST
#
#                flight_airport_destination_name  \
# 0                 Bangkok Suvarnabhumi Airport
# 1              Hong Kong International Airport
# 2     Riyadh King Khalid International Airport
# 3  Jeddah King Abdulaziz International Airport
# 4                       Milan Malpensa Airport
#
#   flight_airport_destination_position_country_name  \
# 0                                         Thailand
# 1                                        Hong Kong
# 2                                     Saudi Arabia
# 3                                     Saudi Arabia
# 4                                            Italy
#
#   flight_airport_destination_position_region_city  \
# 0                                         Bangkok
# 1                                       Hong Kong
# 2                                          Riyadh
# 3                                          Jeddah
# 4                                           Milan
#
#   flight_time_scheduled_departure flight_time_scheduled_arrival  \
# 0             2023-03-30 01:05:00           2023-03-30 07:25:00
# 1             2023-03-30 01:10:00           2023-03-30 09:30:00
# 2             2023-03-30 01:30:00           2023-03-30 03:00:00
# 3             2023-03-30 01:40:00           2023-03-30 04:15:00
# 4             2023-03-30 01:45:00           2023-03-30 08:00:00
#
#   scheduled_departure_local_time scheduled_arrival_local_time
# 0      2023-03-30 01:05:00+07:00    2023-03-30 07:25:00+07:00
# 1      2023-03-30 01:10:00+08:00    2023-03-30 09:30:00+08:00
# 2      2023-03-30 01:30:00+03:00    2023-03-30 03:00:00+03:00
# 3      2023-03-30 01:40:00+03:00    2023-03-30 04:15:00+03:00
# 4      2023-03-30 01:45:00+02:00    2023-03-30 08:00:00+02:00

# %%
df_new = df_new.rename(columns={'flight_airline_code_icao': 'ICAO', 'flight_identification_number_default':'Flight ID'
                                ,'flight_status_text':'Flight_Status','flight_airport_destination_timezone_name':'Destination Timezone'
                                ,'flight_airport_destination_name': 'Destination Airport','flight_airport_destination_position_country_name':'Destination Country'
                                ,'flight_airport_destination_position_region_city':'Destination City'
                                , 'flight_time_scheduled_departure': 'Scheduled Departure (UTC)'
                                , 'flight_time_scheduled_arrival': 'Scheduled Arrival (UTC)'
                                , 'scheduled_departure_local_time': 'Schedule Departure Local Time'
                                , 'scheduled_arrival_local_time': 'Schedule Arrival Local Time'})

df_new.head()
# Out:
#   ICAO Flight ID        Flight_Status Destination Timezone  \
# 0  QTR    QR8434            Scheduled         Asia/Bangkok
# 1  QTR    QR8360            Scheduled       Asia/Hong_Kong
# 2  QTR    QR1166            Scheduled          Asia/Riyadh
# 3  QTR    QR1190  Estimated dep 04:40          Asia/Riyadh
# 4  QTR    QR8111  Estimated dep 04:55          Europe/Rome
#
#   flight_airport_destination_timezone_abbr  \
# 0                                      +07
# 1                                      HKT
# 2                                      +03
# 3                                      +03
# 4                                     CEST
#
#                            Destination Airport Destination Country  \
# 0                 Bangkok Suvarnabhumi Airport            Thailand
# 1              Hong Kong International Airport           Hong Kong
# 2     Riyadh King Khalid International Airport        Saudi Arabia
# 3  Jeddah King Abdulaziz International Airport        Saudi Arabia
# 4                       Milan Malpensa Airport               Italy
#
#   Destination City Scheduled Departure (UTC) Scheduled Arrival (UTC)  \
# 0          Bangkok       2023-03-30 01:05:00     2023-03-30 07:25:00
# 1        Hong Kong       2023-03-30 01:10:00     2023-03-30 09:30:00
# 2           Riyadh       2023-03-30 01:30:00     2023-03-30 03:00:00
# 3           Jeddah       2023-03-30 01:40:00     2023-03-30 04:15:00
# 4            Milan       2023-03-30 01:45:00     2023-03-30 08:00:00
#
#   Schedule Departure Local Time Schedule Arrival Local Time
# 0     2023-03-30 01:05:00+07:00   2023-03-30 07:25:00+07:00
# 1     2023-03-30 01:10:00+08:00   2023-03-30 09:30:00+08:00
# 2     2023-03-30 01:30:00+03:00   2023-03-30 03:00:00+03:00
# 3     2023-03-30 01:40:00+03:00   2023-03-30 04:15:00+03:00
# 4     2023-03-30 01:45:00+02:00   2023-03-30 08:00:00+02:00

# %% [markdown]
# ## Import new dataset to be used for connection

# %%
# read new dataset to connect ICAO Codes
df_airline = pd.read_csv('airlines.csv')
df_airline.head()
# Out:
#    Airline ID                                          Name Alias IATA ICAO  \
# 0          -1                                       Unknown    \N    -  NaN
# 1           1                                Private flight    \N    -  NaN
# 2           2                                   135 Airways    \N  NaN  GNL
# 3           3                                 1Time Airline    \N   1T  RNX
# 4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN  WYT
#
#   Callsign         Country Active
# 0       \N              \N      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N

# %%
# Clean read-in data
df_airline.drop('Airline ID',axis = 1, inplace=True)
df_airline.drop('Alias',axis = 1, inplace=True)
df_airline.drop('IATA',axis = 1, inplace=True)
df_airline.head()
# Out:
#                                            Name ICAO Callsign         Country  \
# 0                                       Unknown  NaN       \N              \N
# 1                                Private flight  NaN      NaN             NaN
# 2                                   135 Airways  GNL  GENERAL   United States
# 3                                 1Time Airline  RNX  NEXTIME    South Africa
# 4  2 Sqn No 1 Elementary Flying Training School  WYT      NaN  United Kingdom
#
#   Active
# 0      Y
# 1      Y
# 2      N
# 3      Y
# 4      N

# %%
# merged/join connected data frames to show connection
merged_df = pd.merge(df_new, df_airline, on ='ICAO')
merged_df.head()
# Out:
#   ICAO Flight ID        Flight_Status Destination Timezone  \
# 0  QTR    QR8434            Scheduled         Asia/Bangkok
# 1  QTR    QR8360            Scheduled       Asia/Hong_Kong
# 2  QTR    QR1166            Scheduled          Asia/Riyadh
# 3  QTR    QR1190  Estimated dep 04:40          Asia/Riyadh
# 4  QTR    QR8111  Estimated dep 04:55          Europe/Rome
#
#   flight_airport_destination_timezone_abbr  \
# 0                                      +07
# 1                                      HKT
# 2                                      +03
# 3                                      +03
# 4                                     CEST
#
#                            Destination Airport Destination Country  \
# 0                 Bangkok Suvarnabhumi Airport            Thailand
# 1              Hong Kong International Airport           Hong Kong
# 2     Riyadh King Khalid International Airport        Saudi Arabia
# 3  Jeddah King Abdulaziz International Airport        Saudi Arabia
# 4                       Milan Malpensa Airport               Italy
#
#   Destination City Scheduled Departure (UTC) Scheduled Arrival (UTC)  \
# 0          Bangkok       2023-03-30 01:05:00     2023-03-30 07:25:00
# 1        Hong Kong       2023-03-30 01:10:00     2023-03-30 09:30:00
# 2           Riyadh       2023-03-30 01:30:00     2023-03-30 03:00:00
# 3           Jeddah       2023-03-30 01:40:00     2023-03-30 04:15:00
# 4            Milan       2023-03-30 01:45:00     2023-03-30 08:00:00
#
#   Schedule Departure Local Time Schedule Arrival Local Time           Name  \
# 0     2023-03-30 01:05:00+07:00   2023-03-30 07:25:00+07:00  Qatar Airways
# 1     2023-03-30 01:10:00+08:00   2023-03-30 09:30:00+08:00  Qatar Airways
# 2     2023-03-30 01:30:00+03:00   2023-03-30 03:00:00+03:00  Qatar Airways
# 3     2023-03-30 01:40:00+03:00   2023-03-30 04:15:00+03:00  Qatar Airways
# 4     2023-03-30 01:45:00+02:00   2023-03-30 08:00:00+02:00  Qatar Airways
#
#   Callsign Country Active
# 0   QATARI   Qatar      Y
# 1   QATARI   Qatar      Y
# 2   QATARI   Qatar      Y
# 3   QATARI   Qatar      Y
# 4   QATARI   Qatar      Y

# %%
# send to flat file
df_new.to_csv('flightinfo.csv')
df_airline.to_csv('airlineinfo.csv')

# %% [markdown]
# ## Conclusion
# In summary, building such a pipeline has displayed the power and efficiency that can be pursued of API Calling even in a personal project. Although REST APIs in particular seem to be quite static and hard to use from the outside, working with them directly and with guidance along the way has shown the overall power especially due to the natural automation of the pipeline. Despite the fact that there is room for improvement, I feel that this is a good starting point for the building of data workflows within an API.
